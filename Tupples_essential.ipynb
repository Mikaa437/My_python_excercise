# %%
products=('lemon', 'mango', 'orange')
products
# Out:
# ('lemon', 'mango', 'orange')

# %%
product_information= ('mango', 1.4,[15,20])
len(product_information)
# Out:
# 3

# %%
# convert tupple into a list
product_information=list(product_information)
product_information
# Out:
# ['mango', 1.4, [15, 20]]

# %%
# changing the parameter in the list (we need to convert tupple into list to change the parameters)
product_information[1]=1.8
product_information
# Out:
# ['mango', 1.8, [15, 20]]

# %%
# converting list into a tuple
product_information=tuple(product_information)
product_information
# Out:
# ('mango', 1.8, [15, 20])

# %%
type(product_information)
# Out:
# tuple

# %%
type(product_information[2])
# Out:
# list

# %%
product_information[2][1]=10
product_information
# Out:
# ('mango', 1.8, [15, 10])

# %%
#creating a string
fruit=('mango')
type(fruit)
# Out:
# str

# %%
#creating a tupple (difference is a "," at the end inside the bracket)
fruit=('mango',)
type(fruit)
# Out:
# tuple

# %%
# MANIPULATIONG TABLES
mango_info= ('fruits', 1.4, [10,15])
lemon_info= ('fruits', 0.9, [5,8])

# %%
dir(mango_info)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
product_info= mango_info+lemon_info
product_info
# Out:
# ('fruits', 1.4, [10, 15], 'fruits', 0.9, [5, 8])

# %%
product_info.count('fruits')
# Out:
# 2

# %%
product_info.index(0.9)
# Out:
# 4

# %%
product_info[1]
# Out:
# 1.4

# %%
product_info[-5]
# Out:
# 1.4

# %%
product_info[:]
# Out:
# ('fruits', 1.4, [10, 15], 'fruits', 0.9, [5, 8])

# %%
#index on the right is not taken into account
product_info[2:5]
# Out:
# ([10, 15], 'fruits', 0.9)

# %%
product_info[3:]
# Out:
# ('fruits', 0.9, [5, 8])

# %%
product_info[:3]
# Out:
# ('fruits', 1.4, [10, 15])

# %%
product_info[5][1]
# Out:
# 8

# %%
# PACKING AND UNPACKING
# packing
quantity=(10,20,30)
quantity
# Out:
# (10, 20, 30)

# %%
# unpacking
(apple, orange,lime)=(10,20,30)

# %%
apple
# Out:
# 10

# %%
orange
# Out:
# 20

# %%
# when there is one element more on right hand side
(apple, orange,lime, _)=[10,20,30,40]

# %%
_
# Out:
# 40

# %%
# when we want to assing to one element more than one variables
(apple, orange,*lime)=[10,20,30,40,50,60]
lime
# Out:
# [30, 40, 50, 60]
