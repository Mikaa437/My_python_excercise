# %%
products=['apple', 'banana', 'orange', 'pineapple', 'mango', 'pear', 'grapes','lemon']
products
# Out:
# ['apple', 'banana', 'orange', 'pineapple', 'mango', 'pear', 'grapes', 'lemon']

# %%
# displaying element with given negative index (starting from right hand side)
products[-1]
# Out:
# 'lemon'

# %%
# checking what is the index of the element
products.index('lemon')
# Out:
# 7

# %%
# displaying element with given index
products[7]
# Out:
# 'lemon'

# %%
# checking the existence of element in the list
'mango' in products
# Out:
# True

# %%
'apple' not in products
# Out:
# False

# %%
# replacing elements
products[0]='kiwi'
products
# Out:
# ['kiwi', 'banana', 'orange', 'pineapple', 'mango', 'pear', 'grapes', 'lemon']

# %%
# displaying elements with given index range (element with index 4 is not in subset)
products[2:4]
# Out:
# ['orange', 'pineapple']

# %%
products[2:]
# Out:
# ['orange', 'pineapple', 'mango', 'pear', 'grapes', 'lemon']

# %%
products[:6]
# Out:
# ['kiwi', 'banana', 'orange', 'pineapple', 'mango', 'pear']

# %%
products[-6:-5]
# Out:
# ['orange']

# %%
products[-1:]
# Out:
# ['lemon']

# %%
#adding new list element
products.append('waterlemon')
products
# Out:
# ['kiwi',
#  'banana',
#  'orange',
#  'pineapple',
#  'mango',
#  'pear',
#  'grapes',
#  'lemon',
#  'waterlemon']

# %%
# removing list last element
products.pop()
products
# Out:
# ['kiwi', 'banana', 'orange', 'pineapple', 'mango', 'pear', 'grapes', 'lemon']

# %%
# removing any element
products.remove('apple')
products
# Out:
# ['banana', 'orange', 'pineapple', 'mango', 'pear', 'grapes', 'lemon']

# %%
# adding elements in given place
products.insert(1,'apple')
products
# Out:
# ['banana', 'apple', 'orange', 'pineapple', 'mango', 'pear', 'grapes', 'lemon']

# %%
electronics=['TV','laptop']
electronics
# Out:
# ['TV', 'laptop']

# %%
# adding multiple elements into the list
products.extend(electronics)
products
# Out:
# ['banana',
#  'apple',
#  'orange',
#  'pineapple',
#  'mango',
#  'pear',
#  'grapes',
#  'lemon',
#  'TV',
#  'laptop']

# %%
# deleting all elements in the list
electronics.clear()
electronics
# Out:
# []

# %%
products
# Out:
# ['banana',
#  'apple',
#  'orange',
#  'pineapple',
#  'mango',
#  'pear',
#  'grapes',
#  'lemon',
#  'TV',
#  'laptop']

# %%
# aliasing
quantity= [2,4,6]
quantity
# Out:
# [2, 4, 6]

# %%
quantity_clon=quantity

# %%
quantity is quantity_clon
# Out:
# True

# %%
quantity_clon.append(10)
quantity_clon
quantity
# Out:
# [2, 4, 6, 10, 10, 10]

# %%
quantity_clon
quantity
# Out:
# [2, 4, 6, 10, 10, 10]

# %%
# cloning
quantity_clone=list(quantity)
quantity_clone
# Out:
# [2, 4, 6, 10, 10, 10]

# %%
# clonning different way
quantity_clone=quantity[:]
quantity_clone
# Out:
# [2, 4, 6, 10, 10, 10]

# %%
quantity_clone.append(12)
quantity_clone
# Out:
# [2, 4, 6, 10, 10, 10, 12, 12, 12, 12]

# %%
quantity
# Out:
# [2, 4, 6, 10, 10, 10]

# %%
# sorting
products
# Out:
# ['banana',
#  'apple',
#  'orange',
#  'pineapple',
#  'mango',
#  'pear',
#  'grapes',
#  'lemon',
#  'TV',
#  'laptop']

# %%
products.sort()
products
# Out:
# ['TV',
#  'apple',
#  'banana',
#  'grapes',
#  'laptop',
#  'lemon',
#  'mango',
#  'orange',
#  'pear',
#  'pineapple']

# %%
# na odwrót
rzeczy=['laptop', 'myszka', 'sluchawki']
rzeczy.reverse()
rzeczy
# Out:
# ['sluchawki', 'myszka', 'laptop']

# %%
basket=products+rzeczy
basket
# Out:
# ['TV',
#  'apple',
#  'banana',
#  'grapes',
#  'laptop',
#  'lemon',
#  'mango',
#  'orange',
#  'pear',
#  'pineapple',
#  'sluchawki',
#  'myszka',
#  'laptop']

# %%
# couting the elements
basket.count('laptop')
# Out:
# 2

# %%
# spliting the list
text='Welcome to our store'
text.split()
# Out:
# ['Welcome', 'to', 'our', 'store']
